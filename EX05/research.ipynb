# %% [markdown]
# ## Import Libraries and Describing our data
# Reads a CSV file `(speed_data_data.csv)` into a pandas DataFrame called `df`.
# Calls the `describe()` function on the DataFrame to display summary statistics of the dataset.

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
import torch
import torch.nn as nn
import torch.optim as optim

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

from typing import List, Tuple, Union

df = pd.read_csv('./data/speed_data_data.csv', engine='python', encoding='utf-8')
df.describe()
# Out:
#             gender          age         income         goal          dec  \
# count  8378.000000  8283.000000    4279.000000  8299.000000  8378.000000
# mean      0.500597    26.358928   44887.606450     2.122063     0.419909
# std       0.500029     3.566763   17206.920962     1.407181     0.493573
# min       0.000000    18.000000    8607.000000     1.000000     0.000000
# 25%       0.000000    24.000000   31516.000000     1.000000     0.000000
# 50%       1.000000    26.000000   43185.000000     2.000000     0.000000
# 75%       1.000000    28.000000   54303.000000     2.000000     1.000000
# max       1.000000    55.000000  109031.000000     6.000000     1.000000
#
#               attr         sinc        intel          fun          amb  \
# count  8176.000000  8101.000000  8082.000000  8028.000000  7666.000000
# mean      6.189995     7.175164     7.368597     6.400598     6.777524
# std       1.950169     1.740315     1.550453     1.953702     1.794055
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     6.000000     6.000000     5.000000     6.000000
# 50%       6.000000     7.000000     7.000000     7.000000     7.000000
# 75%       8.000000     8.000000     8.000000     8.000000     8.000000
# max      10.000000    10.000000    10.000000    10.000000    10.000000
#
#               shar         like         prob          met
# count  7311.000000  8138.000000  8069.000000  8003.000000
# mean      5.474559     6.134087     5.207523     0.948769
# std       2.156363     1.841285     2.129565     0.989889
# min       0.000000     0.000000     0.000000     0.000000
# 25%       4.000000     5.000000     4.000000     0.000000
# 50%       6.000000     6.000000     5.000000     0.000000
# 75%       7.000000     7.000000     7.000000     2.000000
# max      10.000000    10.000000    10.000000     8.000000

# %% [markdown]
# Based on the provided `describe()` output of the dataset, we can observe the following:
#
# * The count of values `varies` for each column, indicating the `presence of missing data`.
# * The `mean value` of the `gender column` is approximately `0.5006`, which suggests an `approximately equal distribution between genders` (0 representing one gender and 1 representing the other).
# * The average dec value is around `0.42`, indicating that approximately `42%` of the participants got a date.
#
# Where Ploting the result to make it easier to visualize.

# %%
df.hist(figsize=(20, 15))
plt.show()

# %%
cp_df = df.copy()
corr = cp_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /tmp/ipykernel_28516/1199475976.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = cp_df.corr()
# <style type="text/css">
# #T_f7cc9_row0_col0, #T_f7cc9_row1_col1, #T_f7cc9_row2_col2, #T_f7cc9_row3_col3, #T_f7cc9_row4_col4, #T_f7cc9_row5_col5, #T_f7cc9_row6_col6, #T_f7cc9_row7_col7, #T_f7cc9_row8_col8, #T_f7cc9_row9_col9, #T_f7cc9_row10_col10, #T_f7cc9_row11_col11, #T_f7cc9_row12_col12, #T_f7cc9_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f7cc9_row0_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_f7cc9_row0_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_f7cc9_row0_col3, #T_f7cc9_row0_col8, #T_f7cc9_row0_col11, #T_f7cc9_row2_col12 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_f7cc9_row0_col4, #T_f7cc9_row3_col0, #T_f7cc9_row11_col13 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_f7cc9_row0_col5, #T_f7cc9_row6_col13, #T_f7cc9_row13_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_f7cc9_row0_col6, #T_f7cc9_row0_col12, #T_f7cc9_row2_col10, #T_f7cc9_row13_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_f7cc9_row0_col7, #T_f7cc9_row0_col9, #T_f7cc9_row1_col2, #T_f7cc9_row1_col6, #T_f7cc9_row1_col13, #T_f7cc9_row2_col3, #T_f7cc9_row2_col5, #T_f7cc9_row2_col8, #T_f7cc9_row2_col11, #T_f7cc9_row3_col4, #T_f7cc9_row3_col10, #T_f7cc9_row3_col12, #T_f7cc9_row9_col0, #T_f7cc9_row13_col1, #T_f7cc9_row13_col5, #T_f7cc9_row13_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f7cc9_row0_col10, #T_f7cc9_row2_col6, #T_f7cc9_row3_col6, #T_f7cc9_row13_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_f7cc9_row0_col13, #T_f7cc9_row12_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_f7cc9_row1_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_f7cc9_row1_col3, #T_f7cc9_row3_col9, #T_f7cc9_row6_col0, #T_f7cc9_row7_col13, #T_f7cc9_row8_col13, #T_f7cc9_row11_col1, #T_f7cc9_row12_col13 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_f7cc9_row1_col4, #T_f7cc9_row1_col11, #T_f7cc9_row1_col12, #T_f7cc9_row13_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_f7cc9_row1_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_f7cc9_row1_col7, #T_f7cc9_row1_col9 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_f7cc9_row1_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_f7cc9_row1_col10, #T_f7cc9_row3_col8 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_f7cc9_row2_col0, #T_f7cc9_row4_col1, #T_f7cc9_row4_col13, #T_f7cc9_row7_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_f7cc9_row2_col1, #T_f7cc9_row2_col4, #T_f7cc9_row4_col3, #T_f7cc9_row7_col0, #T_f7cc9_row10_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_f7cc9_row2_col7, #T_f7cc9_row3_col11, #T_f7cc9_row13_col10 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_f7cc9_row2_col9 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_f7cc9_row2_col13 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_f7cc9_row3_col1, #T_f7cc9_row9_col4 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_f7cc9_row3_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_f7cc9_row3_col5, #T_f7cc9_row9_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f7cc9_row3_col7, #T_f7cc9_row6_col2, #T_f7cc9_row8_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_f7cc9_row3_col13, #T_f7cc9_row13_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_f7cc9_row4_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_f7cc9_row4_col2, #T_f7cc9_row5_col13, #T_f7cc9_row7_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_f7cc9_row4_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_f7cc9_row4_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_f7cc9_row4_col7, #T_f7cc9_row4_col9 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_f7cc9_row4_col8, #T_f7cc9_row5_col7 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_f7cc9_row4_col10, #T_f7cc9_row6_col5, #T_f7cc9_row6_col10, #T_f7cc9_row7_col10, #T_f7cc9_row8_col12, #T_f7cc9_row10_col4 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_f7cc9_row4_col11 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_f7cc9_row4_col12 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_f7cc9_row5_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_f7cc9_row5_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f7cc9_row5_col2, #T_f7cc9_row8_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_f7cc9_row5_col3, #T_f7cc9_row9_col3, #T_f7cc9_row12_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_f7cc9_row5_col4, #T_f7cc9_row10_col12 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_f7cc9_row5_col6, #T_f7cc9_row7_col5 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_f7cc9_row5_col8 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_f7cc9_row5_col9, #T_f7cc9_row8_col4 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_f7cc9_row5_col10, #T_f7cc9_row8_col6, #T_f7cc9_row10_col5, #T_f7cc9_row10_col9, #T_f7cc9_row11_col12 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_f7cc9_row5_col11, #T_f7cc9_row7_col9, #T_f7cc9_row11_col10 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_f7cc9_row5_col12 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_f7cc9_row6_col1, #T_f7cc9_row10_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_f7cc9_row6_col3, #T_f7cc9_row10_col2, #T_f7cc9_row11_col3, #T_f7cc9_row13_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_f7cc9_row6_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_f7cc9_row6_col7 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_f7cc9_row6_col8, #T_f7cc9_row7_col8 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_f7cc9_row6_col9, #T_f7cc9_row7_col11 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_f7cc9_row6_col11, #T_f7cc9_row11_col4, #T_f7cc9_row11_col6 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_f7cc9_row6_col12 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_f7cc9_row7_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_f7cc9_row7_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_f7cc9_row7_col6 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_f7cc9_row7_col12 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_f7cc9_row8_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_f7cc9_row8_col2, #T_f7cc9_row13_col12 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_f7cc9_row8_col5 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_f7cc9_row8_col7 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_f7cc9_row8_col9, #T_f7cc9_row11_col7 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_f7cc9_row8_col10 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_f7cc9_row8_col11 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_f7cc9_row9_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_f7cc9_row9_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_f7cc9_row9_col6 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_f7cc9_row9_col7 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_f7cc9_row9_col8, #T_f7cc9_row11_col9 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_f7cc9_row9_col10, #T_f7cc9_row9_col11 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_f7cc9_row9_col12 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_f7cc9_row9_col13 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f7cc9_row10_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_f7cc9_row10_col6 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_f7cc9_row10_col7 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_f7cc9_row10_col8 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_f7cc9_row10_col11 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_f7cc9_row10_col13 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_f7cc9_row11_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_f7cc9_row11_col2, #T_f7cc9_row13_col7 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_f7cc9_row11_col5 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_f7cc9_row11_col8 {
#   background-color: #f7af9

# %% [markdown]
# From the correlation matrix, we can observe the following:
#
# - The correlation values range from -1 to 1, representing the strength and direction of the linear relationship between pairs of variables. A correlation coefficient of 1 indicates a perfect positive correlation, -1 indicates a perfect negative correlation, and 0 indicates no correlation.
# - The diagonal values of the correlation matrix are all 1, which is expected since they represent the correlation of each variable with itself.
# - There are some variables that show a moderate positive correlation with each other. For example, the variables `dec` (decision) and `attr` (attractiveness) have a correlation coefficient of 0.49, indicating a moderate positive relationship.
# - Some variables have weak positive or negative correlations with each other. For instance, the variables `gender` and `age` have a correlation coefficient of 0.071, suggesting a weak positive relationship.
# - It's worth noting that correlation does not imply causation. The correlation coefficients only capture the linear relationship between variables and do not provide information about the underlying causes or direction of the relationship.
#
# From this correlation matrix we can see that the features `attr`, `sinc`, `fun`, `amb`, `shar`, `like`, `prob` seems to have greate impact on `dec` which is the value we will try to predict.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

def split_data(X: np.ndarray, y: np.ndarray, test_size: float = 0.2, random_state: int = 42) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]:
    """
    Split the data into training, validation, and test sets, and convert them to PyTorch tensors.

    Args:
        X (np.ndarray): Input features.
        y (np.ndarray): Target labels.
        test_size (float, optional): The proportion of the dataset to include in the test split.
            Defaults to 0.2.
        random_state (int, optional): Controls the shuffling applied to the data before splitting.
            Defaults to 42.

    Returns:
        Tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]:
            A tuple containing the training, validation, and test sets as PyTorch tensors:
            - X_train_tensor: Training features tensor.
            - X_val_tensor: Validation features tensor.
            - X_test_tensor: Test features tensor.
            - y_train_tensor: Training labels tensor.
            - y_val_tensor: Validation labels tensor.
            - y_test_tensor: Test labels tensor.
    """
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=test_size, random_state=random_state)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    X_train_tensor = torch.from_numpy(X_train).float().to(device)
    y_train_tensor = torch.from_numpy(y_train).float().to(device)
    X_val_tensor = torch.from_numpy(X_val).float().to(device)
    y_val_tensor = torch.from_numpy(y_val).float().to(device)
    X_test_tensor = torch.from_numpy(X_test).float().to(device)
    y_test_tensor = torch.from_numpy(y_test).float().to(device)

    return X_train_tensor, X_val_tensor, X_test_tensor, y_train_tensor, y_val_tensor, y_test_tensor

# Using result form the corelation matrix we can isolate those paramteres for training
rating_features = ['attr', 'sinc', 'fun', 'amb', 'shar', 'like', 'prob']

X = df.drop('dec', axis=1)
X_copy = X

# Data X
X = df[rating_features].values
y = df['dec'].values

imputer = SimpleImputer(strategy='most_frequent')
X = imputer.fit_transform(X)

X_train_tensor, X_val_tensor, X_test_tensor, y_train_tensor, y_val_tensor, y_test_tensor = split_data(X, y)
# Out:
# Device: cpu

# %% [markdown]
# The code snippet performs the following tasks:
#
# 1. Checks the availability of a CUDA-enabled GPU device. If a CUDA device is available, it sets the device variable to "cuda"; otherwise, it sets it to "cpu". This allows the code to utilize GPU acceleration if possible.
#
# 2. Defines a function named `split_data` that takes input features (`X`) and target variable (`y`) as NumPy arrays, along with optional parameters for test size and random state. It uses scikit-learn's `train_test_split` function to split the data into train, validation, and test sets. The train-test split is performed twice: first to split the data into train and validation sets, and then to split the train set further into train and test sets.
#
# 3. Converts the NumPy arrays into PyTorch tensors and moves them to the chosen device (GPU or CPU) using `torch.from_numpy().float().to(device)`. This ensures that the data is in the correct format and on the appropriate device for training and inference.
#
# 4. Returns the train, validation, and test data tensors (`X_train_tensor`, `X_val_tensor`, `X_test_tensor`, `y_train_tensor`, `y_val_tensor`, `y_test_tensor`) as a tuple.
#
# The code snippet sets up the data preprocessing and splitting steps necessary before training a PyTorch model. It also ensures that the data is properly formatted and ready to be fed into a model for training and evaluation.

# %% [markdown]
# # Setting Up for Training
# ---

# %%
class LogisticRegression(nn.Module):
    def __init__(self, input_size):
        super(LogisticRegression, self).__init__()
        self.linear = nn.Linear(input_size, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        out = self.linear(x)
        out = self.sigmoid(out)
        return out

def grid_search(X_train: np.ndarray, y_train: np.ndarray, X_val: np.ndarray, y_val: np.ndarray,
                learning_rates: List[float], num_epochs_list: List[int]) -> Tuple[float, int]:
    """
    Perform a grid search to find the best combination of learning rate and number of epochs.

    Args:
        X_train (np.ndarray): Training features.
        y_train (np.ndarray): Training labels.
        X_val (np.ndarray): Validation features.
        y_val (np.ndarray): Validation labels.
        learning_rates (List[float]): List of learning rates to try.
        num_epochs_list (List[int]): List of numbers of epochs to try.

    Returns:
        Tuple[float, int]: A tuple containing the best learning rate, best number of epochs, and the best accuracy score.
    """

    best_learning_rate = None
    best_num_epochs = None
    best_accuracy = 0.0

    for learning_rate in learning_rates:
        for num_epochs in num_epochs_list:
            # Create the model
            model = LogisticRegression(input_size=X_train.shape[1]).to(device)

            # Define the loss function and optimizer
            criterion = nn.BCELoss()
            optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

            # Train the model
            _, _, train_accuracy_scores, val_accuracy_scores = train_model(model, criterion, optimizer,
                                                                           num_epochs, X_train, y_train, X_val, y_val)

            # Get the accuracy score from the validation set
            accuracy = val_accuracy_scores[-1]

            # Track the best learning rate and number of epochs
            if accuracy > best_accuracy:
                best_accuracy = accuracy
                best_learning_rate = learning_rate
                best_num_epochs = num_epochs

            print(f"Learning Rate: {learning_rate:.4f}, Number of Epochs: {num_epochs}, Validation Accuracy: {accuracy:.2%}")

    return best_learning_rate, best_num_epochs

def grid_search_epochs(X_train: np.ndarray, y_train: np.ndarray, X_val: np.ndarray, y_val: np.ndarray,
                       num_epochs_list: List[int], learning_rate: float) -> int:
    """
    Perform a grid search to find the best number of epochs for a given learning rate.

    Args:
        X_train (np.ndarray): Training features.
        y_train (np.ndarray): Training labels.
        X_val (np.ndarray): Validation features.
        y_val (np.ndarray): Validation labels.
        num_epochs_list (List[int]): List of numbers of epochs to try.
        learning_rate (float): Learning rate to use.

    Returns:
        int: The best number of epochs based on validation performance.
    """

    best_num_epochs = None
    best_accuracy = 0.0

    for num_epochs in num_epochs_list:
        # Create the model
        model = LogisticRegression(input_size=X_train.shape[1]).to(device)

        # Define the loss function and optimizer
        criterion = nn.BCELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

        # Train the model
        _, _, train_accuracy_scores, val_accuracy_scores = train_model(model, criterion, optimizer,
                                                                       num_epochs, X_train, y_train, X_val, y_val)

        # Get the accuracy score from the validation set
        accuracy = val_accuracy_scores[-1]

        # Track the best number of epochs
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_num_epochs = num_epochs

        print(f"Number of Epochs: {num_epochs}, Validation Accuracy: {accuracy:.2%}")

    return best_num_epochs

def plot_training_stats(num_epochs: int, train_accuracy_scores: List[float], val_accuracy_scores: List[float],
                        train_losses: List[float], val_losses: List[float], lr: float) -> None:
    """
    Plot the training statistics including accuracy and loss curves.

    Args:
        num_epochs (int): Number of epochs.
        train_accuracy_scores (List[float]): List of training accuracy scores.
        val_accuracy_scores (List[float]): List of validation accuracy scores.
        train_losses (List[float]): List of training loss values.
        val_losses (List[float]): List of validation loss values.
        lr (float): Learning rate.

    Returns:
        None
    """

    # Plot accuracy scores
    plt.plot(range(1, num_epochs + 1), train_accuracy_scores, label='Train Accuracy')
    plt.plot(range(1, num_epochs + 1), val_accuracy_scores, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy Score')
    plt.title(f'Training and Validation Accuracy with model (lr={lr} and epochs={num_epochs})')
    plt.legend()
    plt.show()

    # Plot losses
    plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss')
    plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'Training and Validation Loss with model (lr={lr} and epochs={num_epochs})')
    plt.legend()
    plt.show()

def grid_search_learning_rate(X_train: np.ndarray, y_train: np.ndarray, X_val: np.ndarray, y_val: np.ndarray,
                              learning_rates: List[float]) -> float:
    """
    Perform grid search to find the best learning rate.

    Args:
        X_train (np.ndarray): Training data inputs.
        y_train (np.ndarray): Training data labels.
        X_val (np.ndarray): Validation data inputs.
        y_val (np.ndarray): Validation data labels.
        learning_rates (List[float]): List of learning rates to try.

    Returns:
        float: Best learning rate.
    """

    best_learning_rate = None
    best_accuracy = 0.0

    for learning_rate in learning_rates:
        # Create the model
        model = LogisticRegression(input_size=X_train.shape[1]).to(device)

        # Define the loss function and optimizer
        criterion = nn.BCELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

        # Train the model
        _, _, train_accuracy_scores, val_accuracy_scores = train_model(model, criterion, optimizer,
                                                                       num_epochs, X_train, y_train, X_val, y_val)

        # Get the accuracy score from the validation set
        accuracy = val_accuracy_scores[-1]

        # Track the best learning rate
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_learning_rate = learning_rate

        print(f"Learning Rate: {learning_rate:.4f}, Validation Accuracy: {accuracy:.2%}")

    return best_learning_rate

def train_model(model: nn.Module, criterion: nn.Module, optimizer: torch.optim.Optimizer, num_epochs: int,
                X_train: torch.Tensor, y_train: torch.Tensor, X_val: torch.Tensor, y_val: torch.Tensor) -> Tuple[List[float], List[float], List[float], List[float]]:
    """
    Train the model and track training statistics.

    Args:
        model (nn.Module): Model to be trained.
        criterion (nn.Module): Loss function.
        optimizer (torch.optim.Optimizer): Optimizer for updating model parameters.
        num_epochs (int): Number of training epochs.
        X_train (torch.Tensor): Training data inputs.
        y_train (torch.Tensor): Training data labels.
        X_val (torch.Tensor): Validation data inputs.
        y_val (torch.Tensor): Validation data labels.

    Returns:
        Tuple[List[float], List[float], List[float], List[float]]: Training and validation statistics.
            - train_losses: List of training losses at each epoch.
            - val_losses: List of validation losses at each epoch.
            - train_accuracy_scores: List of training accuracy scores at each epoch.
            - val_accuracy_scores: List of validation accuracy scores at each epoch.
    """

    train_losses = []
    val_losses = []
    train_accuracy_scores = []
    val_accuracy_scores = []

    for epoch in range(num_epochs):
        # Training
        model.train()
        outputs = model(X_train.float())
        loss = criterion(outputs, y_train.unsqueeze(1))
        train_losses.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_pred = np.round(outputs.detach().cpu().numpy())
        train_target = np.round(y_train.detach().cpu().numpy())
        train_accuracy = accuracy_score(train_target, train_pred)
        train_accuracy_scores.append(train_accuracy)

        # Validation
        model.eval()
        with torch.no_grad():
            val_outputs = model(X_val.float())
            val_loss = criterion(val_outputs, y_val.unsqueeze(1))
            val_losses.append(val_loss.item())

            val_pred = np.round(val_outputs.detach().cpu().numpy())
            val_target = np.round(y_val.detach().cpu().numpy())
            val_accuracy = accuracy_score(val_target, val_pred)
            val_accuracy_scores.append(val_accuracy)

        if (epoch + 1) % 100 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {loss.item():.4f}, Val Loss: {val_loss.item():.4f}")

    return train_losses, val_losses, train_accuracy_scores, val_accuracy_scores

def evaluate_model(model: nn.Module, X_test: torch.Tensor, y_test: torch.Tensor) -> np.ndarray:
    """
    Evaluate the trained model on the test set.

    Args:
        model (nn.Module): Trained model.
        X_test (torch.Tensor): Test set inputs.
        y_test (torch.Tensor): Test set labels.

    Returns:
        np.ndarray: Predicted values from the model.
    """

    with torch.no_grad():
        predicted = model(X_test).detach().cpu().numpy()

    return predicted

# %% [markdown]
# The code provided implements several functions for training, evaluating, and conducting a grid search for a logistic regression model implemented using PyTorch.
#
# Here's a brief explanation of each function:
#
# - LogisticRegression: This class represents the logistic regression model. It takes the input size as a parameter and defines the linear layer and sigmoid activation function used in the forward pass.
#
# - grid_search: This function performs a grid search over different learning rates and number of epochs to find the best combination that yields the highest validation accuracy. It initializes a logistic regression model, defines the loss function and optimizer, and trains the model using the train_model function. It tracks the best learning rate, number of epochs, and validation accuracy throughout the grid search.
#
# - grid_search_epochs: This function performs a grid search over different numbers of epochs, keeping the learning rate constant. It follows a similar process as grid_search but focuses only on the number of epochs.
#
# - plot_training_stats: This function plots the training and validation accuracy scores, as well as the training and validation losses, over the epochs. It takes the number of epochs, accuracy scores, loss values, and learning rate as parameters.
#
# - grid_search_learning_rate: This function performs a grid search over different learning rates, keeping the number of epochs constant. It follows a similar process as grid_search but focuses only on the learning rate.
#
# - train_model: This function trains the logistic regression model. It takes the model, loss criterion, optimizer, number of epochs, training data, and validation data as parameters. It iterates over the specified number of epochs, performs forward and backward passes, calculates the training and validation losses, and tracks the accuracy scores. It returns the training and validation losses, as well as the training and validation accuracy scores.
#
# - evaluate_model: This function evaluates the trained model on the test data. It takes the model, test data, and corresponding labels as parameters. It performs forward pass on the test data, obtains the predicted probabilities, and returns the predicted values.
#
# The code snippet provides a set of functions that can be used for training, evaluating, and tuning a logistic regression model in PyTorch.

# %%
learning_rates = [0.001, 0.01, 0.1]
num_epochs_list = [10, 20, 50, 100, 200, 500, 1000, 2000, 5000]
best_learning_rate, best_num_epochs = grid_search(X_train_tensor, y_train_tensor, X_val_tensor, y_val_tensor,
                                                  learning_rates, num_epochs_list)

model = LogisticRegression(input_size=X.shape[1]).to(device)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=best_learning_rate)

print("Best Learning Rate:", best_learning_rate)
print("Best Number of Epochs:", best_num_epochs)

train_losses, val_losses, train_accuracy_scores, val_accuracy_scores = train_model(model, criterion, optimizer, best_num_epochs, X_train_tensor, y_train_tensor, X_val_tensor, y_val_tensor)
plot_training_stats(best_num_epochs, train_accuracy_scores, val_accuracy_scores, train_losses, val_losses, best_learning_rate)

# Step 4: Evaluate the model
predicted_train = evaluate_model(model, X_train_tensor, y_train_tensor)
predicted_test = evaluate_model(model, X_test_tensor, y_test_tensor)
# Out:
# Learning Rate: 0.0010, Number of Epochs: 10, Validation Accuracy: 42.21%
# Learning Rate: 0.0010, Number of Epochs: 20, Validation Accuracy: 56.15%
# Learning Rate: 0.0010, Number of Epochs: 50, Validation Accuracy: 45.04%
# Epoch [100/100], Train Loss: 0.6450, Val Loss: 0.6528
# Learning Rate: 0.0010, Number of Epochs: 100, Validation Accuracy: 59.43%
# Epoch [100/200], Train Loss: 0.8113, Val Loss: 0.8049
# Epoch [200/200], Train Loss: 0.7109, Val Loss: 0.7072
# Learning Rate: 0.0010, Number of Epochs: 200, Validation Accuracy: 53.99%
# Epoch [100/500], Train Loss: 0.7475, Val Loss: 0.7374
# Epoch [200/500], Train Loss: 0.6598, Val Loss: 0.6617
# Epoch [300/500], Train Loss: 0.6541, Val Loss: 0.6561
# Epoch [400/500], Train Loss: 0.6477, Val Loss: 0.6499
# Epoch [500/500], Train Loss: 0.6408, Val Loss: 0.6433
# Learning Rate: 0.0010, Number of Epochs: 500, Validation Accuracy: 61.52%
# Epoch [100/1000], Train Loss: 0.7745, Val Loss: 0.7833
# Epoch [200/1000], Train Loss: 0.7501, Val Loss: 0.7581
# Epoch [300/1000], Train Loss: 0.7223, Val Loss: 0.7295
# Epoch [400/1000], Train Loss: 0.6942, Val Loss: 0.7007
# Epoch [500/1000], Train Loss: 0.6679, Val Loss: 0.6738
# Epoch [600/1000], Train Loss: 0.6444, Val Loss: 0.6500
# Epoch [700/1000], Train Loss: 0.6242, Val Loss: 0.6296
# Epoch [800/1000], Train Loss: 0.6071, Val Loss: 0.6125
# Epoch [900/1000], Train Loss: 0.5929, Val Loss: 0.5983
# Epoch [1000/1000], Train Loss: 0.5810, Val Loss: 0.5868
# Learning Rate: 0.0010, Number of Epochs: 1000, Validation Accuracy: 69.95%
# Epoch [100/2000], Train Loss: 0.7071, Val Loss: 0.7288
# Epoch [200/2000], Train Loss: 0.6596, Val Loss: 0.6766
# Epoch [300/2000], Train Loss: 0.6239, Val Loss: 0.6375
# Epoch [400/2000], Train Loss: 0.5991, Val Loss: 0.6107
# Epoch [500/2000], Train Loss: 0.5822, Val Loss: 0.5928
# Epoch [600/2000], Train Loss: 0.5704, Val Loss: 0.5808
# Epoch [700/2000], Train Loss: 0.5621, Val Loss: 0.5726
# Epoch [800/2000], Train Loss: 0.5560, Val Loss: 0.5668
# Epoch [900/2000], Train Loss: 0.5513, Val Loss: 0.5626
# Epoch [1000/2000], Train Loss: 0.5476, Val Loss: 0.5593
# Epoch [1100/2000], Train Loss: 0.5444, Val Loss: 0.5566
# Epoch [1200/2000], Train Loss: 0.5417, Val Loss: 0.5542
# Epoch [1300/2000], Train Loss: 0.5392, Val Loss: 0.5520
# Epoch [1400/2000], Train Loss: 0.5369, Val Loss: 0.5500
# Epoch [1500/2000], Train Loss: 0.5347, Val Loss: 0.5480
# Epoch [1600/2000], Train Loss: 0.5326, Val Loss: 0.5461
# Epoch [1700/2000], Train Loss: 0.5305, Val Loss: 0.5441
# Epoch [1800/2000], Train Loss: 0.5285, Val Loss: 0.5422
# Epoch [1900/2000], Train Loss: 0.5265, Val Loss: 0.5403
# Epoch [2000/2000], Train Loss: 0.5246, Val Loss: 0.5384
# Learning Rate: 0.0010, Number of Epochs: 2000, Validation Accuracy: 73.15%
# Epoch [100/5000], Train Loss: 0.6986, Val Loss: 0.7221
# Epoch [200/5000], Train Loss: 0.6414, Val Loss: 0.6595
# Epoch [300/5000], Train Loss: 0.6060, Val Loss: 0.6207
# Epoch [400/5000], Train Loss: 0.5845, Val Loss: 0.5976
# Epoch [500/5000], Train Loss: 0.5713, Val Loss: 0.5837
# Epoch [600/5000], Train Loss: 0.5627, Val Loss: 0.5751
# Epoch [700/5000], Train Loss: 0.5568, Val Loss: 0.5694
# Epoch [800/5000], Train Loss: 0.5525, Val Loss: 0.5654
# Epoch [900/5000], Train Loss: 0.5491, Val Loss: 0.5623
# Epoch [1000/5000], Train Loss: 0.5462, Val Loss: 0.5597
# Epoch [1100/5000], Train Loss: 0.5436, Val Loss: 0.5573
# Epoch [1200/5000], Train Loss: 0.5411, Val Loss: 0.5550
# Epoch [1300/5000], Train Loss: 0.5388, Val Loss: 0.5528
# Epoch [1400/5000], Train Loss: 0.5365, Val Loss: 0.5505
# Epoch [1500/5000], Train Loss: 0.5343, Val Loss: 0.5483
# Epoch [1600/5000], Train Loss: 0.5321, Val Loss: 0.5461
# Epoch [1700/5000], Train Loss: 0.5299, Val Loss: 0.5439
# Epoch [1800/5000], Train Loss: 0.5278, Val Loss: 0.5418
# Epoch [1900/5000], Train Loss: 0.5257, Val Loss: 0.5397
# Epoch [2000/5000], Train Loss: 0.5237, Val Loss: 0.5376
# Epoch [2100/5000], Train Loss: 0.5217, Val Loss: 0.5355
# Epoch [2200/5000], Train Loss: 0.5198, Val Loss: 0.5336
# Epoch [2300/5000], Train Loss: 0.5179, Val Loss: 0.5316
# Epoch [2400/5000], Train Loss: 0.5161, Val Loss: 0.5297
# Epoch [2500/5000], Train Loss: 0.5143, Val Loss: 0.5279
# Epoch [2600/5000], Train Loss: 0.5126, Val Loss: 0.5261
# Epoch [2700/5000], Train Loss: 0.5109, Val Loss: 0.5243
# Epoch [2800/5000], Train Loss: 0.5092, Val Loss: 0.5226
# Epoch [2900/5000], Train Loss: 0.5076, Val Loss: 0.5209
# Epoch [3000/5000], Train Loss: 0.5061, Val Loss: 0.5193
# Epoch [3100/5000], Train Loss: 0.5046, Val Loss: 0.5178
# Epoch [3200/5000], Train Loss: 0.5031, Val Loss: 0.5162
# Epoch [3300/5000], Train Loss: 0.5017, Val Loss: 0.5148
# Epoch [3400/5000], Train Loss: 0.5003, Val Loss: 0.5133
# Epoch [3500/5000], Train Loss: 0.4990, Val Loss: 0.5119
# Epoch [3600/5000], Train Loss: 0.4977, Val Loss: 0.5106
# Epoch [3700/5000], Train Loss: 0.4964, Val Loss: 0.5093
# Epoch [3800/5000], Train Loss: 0.4952, Val Loss: 0.5080
# Epoch [3900/5000], Train Loss: 0.4940, Val Loss: 0.5068
# Epoch [4000/5000], Train Loss: 0.4929, Val Loss: 0.5056
# Epoch [4100/5000], Train Loss: 0.4918, Val Loss: 0.5045
# Epoch [4200/5000], Train Loss: 0.4907, Val Loss: 0.5034
# Epoch [4300/5000], Train Loss: 0.4897, Val Loss: 0.5023
# Epoch [4400/5000], Train Loss: 0.4887, Val Loss: 0.5013
# Epoch [4500/5000], Train Loss: 0.4878, Val Loss: 0.5003
# Epoch [4600/5000], Train Loss: 0.4868, Val Loss: 0.4993
# Epoch [4700/5000], Train Loss: 0.4859, Val Loss: 0.4984
# Epoch [4800/5000], Train Loss: 0.4851, Val Loss: 0.4975
# Epoch [4900/5000], Train Loss: 0.4843, Val Loss: 0.4966
# Epoch [5000/5000], Train Loss: 0.4835, Val Loss: 0.4958
# Learning Rate: 0.0010, Number of Epochs: 5000, Validation Accuracy: 75.69%
# Learning Rate: 0.0100, Number of Epochs: 10, Validation Accuracy: 56.45%
# Learning Rate: 0.0100, Number of Epochs: 20, Validation Accuracy: 55.33%
# Learning Rate: 0.0100, Number of Epochs: 50, Validation Accuracy: 66.37%
# Epoch [100/100], Train Loss: 0.6554, Val Loss: 0.6478
# Learning Rate: 0.0100, Number of Epochs: 100, Validation Accuracy: 62.49%
# Epoch [100/200], Train Loss: 0.7052, Val Loss: 0.7061
# Epoch [200/200], Train Loss: 0.5963, Val Loss: 0.5993
# Learning Rate: 0.0100, Number of Epochs: 200, Validation Accuracy: 70.92%
# Epoch [100/500], Train Loss: 0.7561, Val Loss: 0.7553
# Epoch [200/500], Train Loss: 0.6114, Val Loss: 0.6139
# Epoch [300/500], Train Loss: 0.5611, Val Loss: 0.5678
# Epoch [400/500], Train Loss: 0.5401, Val Loss: 0.5499
# Epoch [500/500], Train Loss: 0.5281, Val Loss: 0.5396
# Learning Rate: 0.0100, Number of Epochs: 500, Validation Accuracy: 72.56%
# Epoch [100/1000], Train Loss: 0.6672, Val Loss: 0.6682
# Epoch [200/1000], Train Loss: 0.5911, Val Loss: 0.5960
# Epoch [300/1000], Train Loss: 0.5562, Val Loss: 0.5653
# Epoch [400/1000], Train Loss: 0.5382, Val Loss: 0.5496
# Epoch [500/1000], Train Loss: 0.5265, Val Loss: 0.5390
# Epoch [600/1000], Train Loss: 0.5173, Val Loss: 0.5303
# Epoch [700/1000], Train Loss: 0.5095, Val Loss: 0.5227
# Epoch [800/1000], Train Loss: 0.5028, Val Loss: 0.5159
# Epoch [900/1000], Train Loss: 0.4970, Val Loss: 0.5100
# Epoch [1000/1000], Train Loss: 0.4920, Val Loss: 0.5048
# Learning Rate: 0.0100, Number of Epochs: 1000, Validation Accuracy: 75.39%
# Epoch [100/2000], Train Loss: 0.6255, Val Loss: 0.6424
# Epoch [200/2000], Train Loss: 0.5610, Val Loss: 0.5721
# Epoch [300/2000], Train Loss: 0.5354, Val Loss: 0.5465
# Epoch [400/2000], Train Loss: 0.5216, Val Loss: 0.5336
# Epoch [500/2000], Train Loss: 0.5118, Val Loss: 0.5245
# Epoch [600/2000], Train Loss: 0.5039, Val Loss: 0.5169
# Epoch [700/2000], Train Loss: 0.4974, Val Loss: 0.5103
# Epoch [800/2000], Train Loss: 0.4919, Val Loss: 0.5046
# Epoch [900/2000], Train Loss: 0.4873, Val Loss: 0.4998
# Epoch [1000/2000], Train Loss: 0.4836, Val Loss: 0.4959
# Epoch [1100/2000], Train Loss: 0.4805, Val Loss: 0.4927
# Epoch [1200/2000], Train Loss: 0.4781, Val Loss: 0.4901
# Epoch [1300/2000], Train Loss: 0.4761, Val Loss: 0.4880
# Epoch [1400/2000], Train Loss: 0.4746, Val Loss: 0.4864
# Epoch [1500/2000], Train Loss: 0.4734, Val Loss: 0.4851
# Epoch [1600/2000], Train Loss: 0.4725, Val Loss: 0.4841
# Epoch [1700/2000], Train Loss: 0.4718, Val Loss: 0.4833
# Epoch [1800/2000], Train Loss: 0.4713, Val Loss: 0.4827
# Epoch [1900/2000], Train Loss: 0.4709, Val Loss: 0.4823
# Epoch [2000/2000], Train Loss: 0.4706, Val Loss: 0.4820
# Learning Rate: 0.0100, Number of Epochs: 2000, Validation Accuracy: 76.36%
# Epoch [100/5000], Train Loss: 0.5797, Val Loss: 0.5811
# Epoch [200/5000], Train Loss: 0.5559, Val Loss: 0.5620
# Epoch [300/5000], Train Loss: 0.5400, Val Loss: 0.5494
# Epoch [400/5000], Train Loss: 0.5285, Val Loss: 0.5397
# Epoch [500/5000], Train Loss: 0.5193, Val Loss: 0.5314
# Epoch [600/5000], Train Loss: 0.5114, Val Loss: 0.5240
# Epoch [700/5000], Train Loss: 0.5046, Val Loss: 0.5174
# Epoch [800/5000], Train Loss: 0.4987, Val Loss: 0.5115
# Epoch [900/5000], Train Loss: 0.4936, Val Loss: 0.5063
# Epoch [1000/5000], Train Loss: 0.4892, Val Loss: 0.5018
# Epoch [1100/5000], Train Loss: 0.4856, Val Loss: 0.4980
# Epoch [1200/5000], Train Loss: 0.4825, Val Loss: 0.4947
# Epoch [1300/5000], Train Loss: 0.4799, Val Loss: 0.4920
# Epoch [1400/5000], Train Loss: 0.4778, Val Loss: 0.4898
# Epoch [1500/5000], Train Loss: 0.4761, Val Loss: 0.4880
# Epoch [1600/5000], Train Loss: 0.4747, Val Loss: 0.4865
# Epoch [1700/5000], Train Loss: 0.4736, Val Loss: 0.4853
# Epoch [1800/5000], Train Loss: 0.4727, Val Loss: 0.4843
# Epoch [1900/5000], Train Loss: 0.4720, Val Loss: 0.4836
# Epoch [2000/5000], Train Loss: 0.4715, Val Loss: 0.4830
# Epoch [2100/5000], Train Loss: 0.4711, Val Loss: 0.4825
# Epoch [2200/5000], Train Loss: 0.4707, Val Loss: 0.4822
# Epoch [2300/5000], Train Loss: 0.4705, Val Loss: 0.4819
# Epoch [2400/5000], Train Loss: 0.4703, Val Loss: 0.4817
# Epoch [2500/5000], Train Loss: 0.4702, Val Loss: 0.4816
# Epoch [2600/5000], Train Loss: 0.4701, Val Loss: 0.4814
# Epoch [2700/5000], Train Loss: 0.4700, Val Loss: 0.4814
# Epoch [2800/5000], Train Loss: 0.4700, Val Loss: 0.4813
# Epoch [2900/5000], Train Loss: 0.4700, Val Loss: 0.4813
# Epoch [3000/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [3100/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [3200/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [3300/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [3400/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [3500/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [3600/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [3700/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [3800/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [3900/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [4000/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [4100/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [4200/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [4300/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [4400/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [4500/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [4600/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [4700/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [4800/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [4900/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [5000/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Learning Rate: 0.0100, Number of Epochs: 5000, Validation Accuracy: 76.29%
# Learning Rate: 0.1000, Number of Epochs: 10, Validation Accuracy: 49.96%
# Learning Rate: 0.1000, Number of Epochs: 20, Validation Accuracy: 60.48%
# Learning Rate: 0.1000, Number of Epochs: 50, Validation Accuracy: 70.02%
# Epoch [100/100], Train Loss: 0.5057, Val Loss: 0.5182
# Learning Rate: 0.1000, Number of Epochs: 100, Validation Accuracy: 75.09%
# Epoch [100/200], Train Loss: 0.5161, Val Loss: 0.5280
# Epoch [200/200], Train Loss: 0.4868, Val Loss: 0.4991
# Learning Rate: 0.1000, Number of Epochs: 200, Validation Accuracy: 75.54%
# Epoch [100/500], Train Loss: 0.5073, Val Loss: 0.5195
# Epoch [200/500], Train Loss: 0.4804, Val Loss: 0.4924
# Epoch [300/500], Train Loss: 0.4724, Val Loss: 0.4840
# Epoch [400/500], Train Loss: 0.4704, Val Loss: 0.4818
# Epoch [500/500], Train Loss: 0.4700, Val Loss: 0.4813
# Learning Rate: 0.1000, Number of Epochs: 500, Validation Accuracy: 76.58%
# Epoch [100/1000], Train Loss: 0.5095, Val Loss: 0.5221
# Epoch [200/1000], Train Loss: 0.4843, Val Loss: 0.4966
# Epoch [300/1000], Train Loss: 0.4745, Val Loss: 0.4862
# Epoch [400/1000], Train Loss: 0.4712, Val Loss: 0.4827
# Epoch [500/1000], Train Loss: 0.4702, Val Loss: 0.4816
# Epoch [600/1000], Train Loss: 0.4700, Val Loss: 0.4813
# Epoch [700/1000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [800/1000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [900/1000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1000/1000], Train Loss: 0.4699, Val Loss: 0.4812
# Learning Rate: 0.1000, Number of Epochs: 1000, Validation Accuracy: 76.29%
# Epoch [100/2000], Train Loss: 0.5154, Val Loss: 0.5284
# Epoch [200/2000], Train Loss: 0.4852, Val Loss: 0.4974
# Epoch [300/2000], Train Loss: 0.4744, Val Loss: 0.4861
# Epoch [400/2000], Train Loss: 0.4711, Val Loss: 0.4825
# Epoch [500/2000], Train Loss: 0.4702, Val Loss: 0.4815
# Epoch [600/2000], Train Loss: 0.4700, Val Loss: 0.4813
# Epoch [700/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [800/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [900/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1000/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1100/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1200/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1300/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1400/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1500/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1600/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1700/2000], Train Loss: 0.4703, Val Loss: 0.4822
# Epoch [1800/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1900/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [2000/2000], Train Loss: 0.4699, Val Loss: 0.4812
# Learning Rate: 0.1000, Number of Epochs: 2000, Validation Accuracy: 76.29%
# Epoch [100/5000], Train Loss: 0.5191, Val Loss: 0.5315
# Epoch [200/5000], Train Loss: 0.4872, Val Loss: 0.4996
# Epoch [300/5000], Train Loss: 0.4753, Val Loss: 0.4871
# Epoch [400/5000], Train Loss: 0.4714, Val Loss: 0.4829
# Epoch [500/5000], Train Loss: 0.4703, Val Loss: 0.4817
# Epoch [600/5000], Train Loss: 0.4700, Val Loss: 0.4813
# Epoch [700/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [800/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [900/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1000/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1100/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1200/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1300/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1400/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1500/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1600/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1700/5000], Train Loss: 0.5054, Val Loss: 0.5112
# Epoch [1800/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1900/5000], Train Loss: 0.4699, Val Loss: 0.4811
# Epoch [2000/5000], Train Loss: 0.4699, Val Loss: 0.4813
# Epoch [2100/5000], Train Loss: 0.4700, Val Loss: 0.4814
# Epoch [2200/5000], Train Loss: 0.4699, Val Loss: 0.4811
# Epoch [2300/5000], Train Loss: 0.4699, Val Loss: 0.4813
# Epoch [2400/5000], Train Loss: 0.4711, Val Loss: 0.4814
# Epoch [2500/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [2600/5000], Train Loss: 0.4700, Val Loss: 0.4810
# Epoch [2700/5000], Train Loss: 0.4822, Val Loss: 0.5011
# Epoch [2800/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [2900/5000], Train Loss: 0.4699, Val Loss: 0.4810
# Epoch [3000/5000], Train Loss: 0.4718, Val Loss: 0.4812
# Epoch [3100/5000], Train Loss: 0.4699, Val Loss: 0.4815
# Epoch [3200/5000], Train Loss: 0.4699, Val Loss: 0.4811
# Epoch [3300/5000], Train Loss: 0.4699, Val Loss: 0.4815
# Epoch [3400/5000], Train Loss: 0.4700, Val Loss: 0.4817
# Epoch [3500/5000], Train Loss: 0.4743, Val Loss: 0.4829
# Epoch [3600/5000], Train Loss: 0.4718, Val Loss: 0.4845
# Epoch [3700/5000], Train Loss: 0.4699, Val Loss: 0.4814
# Epoch [3800/5000], Train Loss: 0.4701, Val Loss: 0.4814
# Epoch [3900/5000], Train Loss: 0.4699, Val Loss: 0.4814
# Epoch [4000/5000], Train Loss: 0.4701, Val Loss: 0.4815
# Epoch [4100/5000], Train Loss: 0.4701, Val Loss: 0.4809
# Epoch [4200/5000], Train Loss: 0.4700, Val Loss: 0.4815
# Epoch [4300/5000], Train Loss: 0.4717, Val Loss: 0.4818
# Epoch [4400/5000], Train Loss: 0.4710, Val Loss: 0.4836
# Epoch [4500/5000], Train Loss: 0.4715, Val Loss: 0.4838
# Epoch [4600/5000], Train Loss: 0.4727, Val Loss: 0.4820
# Epoch [4700/5000], Train Loss: 0.4699, Val Loss: 0.4811
# Epoch [4800/5000], Train Loss: 0.4699, Val Loss: 0.4811
# Epoch [4900/5000], Train Loss: 0.4700, Val Loss: 0.4810
# Epoch [5000/5000], Train Loss: 0.4699, Val Loss: 0.4815
# Learning Rate: 0.1000, Number of Epochs: 5000, Validation Accuracy: 76.66%
# Best Learning Rate: 0.1
# Best Number of Epochs: 5000
# Epoch [100/5000], Train Loss: 0.5246, Val Loss: 0.5364
# Epoch [200/5000], Train Loss: 0.4928, Val Loss: 0.5054
# Epoch [300/5000], Train Loss: 0.4785, Val Loss: 0.4905
# Epoch [400/5000], Train Loss: 0.4729, Val Loss: 0.4845
# Epoch [500/5000], Train Loss: 0.4709, Val Loss: 0.4823
# Epoch [600/5000], Train Loss: 0.4702, Val Loss: 0.4815
# Epoch [700/5000], Train Loss: 0.4700, Val Loss: 0.4813
# Epoch [800/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [900/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1000/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1100/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1200/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1300/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1400/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1500/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1600/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1700/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1800/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [1900/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [2000/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [2100/5000], Train Loss: 0.4742, Val Loss: 0.4857
# Epoch [2200/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [2300/5000], Train Loss: 0.4816, Val Loss: 0.4888
# Epoch [2400/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [2500/5000], Train Loss: 0.4714, Val Loss: 0.4818
# Epoch [2600/5000], Train Loss: 0.4699, Val Loss: 0.4811
# Epoch [2700/5000], Train Loss: 0.4699, Val Loss: 0.4813
# Epoch [2800/5000], Train Loss: 0.4699, Val Loss: 0.4813
# Epoch [2900/5000], Train Loss: 0.4700, Val Loss: 0.4809
# Epoch [3000/5000], Train Loss: 0.4699, Val Loss: 0.4813
# Epoch [3100/5000], Train Loss: 0.4704, Val Loss: 0.4810
# Epoch [3200/5000], Train Loss: 0.4707, Val Loss: 0.4830
# Epoch [3300/5000], Train Loss: 0.4709, Val Loss: 0.4831
# Epoch [3400/5000], Train Loss: 0.4699, Val Loss: 0.4813
# Epoch [3500/5000], Train Loss: 0.4731, Val Loss: 0.4826
# Epoch [3600/5000], Train Loss: 0.4700, Val Loss: 0.4813
# Epoch [3700/5000], Train Loss: 0.4719, Val Loss: 0.4816
# Epoch [3800/5000], Train Loss: 0.4700, Val Loss: 0.4811
# Epoch [3900/5000], Train Loss: 0.4699, Val Loss: 0.4813
# Epoch [4000/5000], Train Loss: 0.4722, Val Loss: 0.4814
# Epoch [4100/5000], Train Loss: 0.4699, Val Loss: 0.4812
# Epoch [4200/5000], Train Loss: 0.4700, Val Loss: 0.4809
# Epoch [4300/5000], Train Loss: 0.4722, Val Loss: 0.4876
# Epoch [4400/5000], Train Loss: 0.4703, Val Loss: 0.4824
# Epoch [4500/5000], Train Loss: 0.4699, Val Loss: 0.4811
# Epoch [4600/5000], Train Loss: 0.4699, Val Loss: 0.4813
# Epoch [4700/5000], Train Loss: 0.4699, Val Loss: 0.4814
# Epoch [4800/5000], Train Loss: 0.4701, Val Loss: 0.4815
# Epoch [4900/5000], Train Loss: 0.4702, Val Loss: 0.4809
# Epoch [5000/5000], Train Loss: 0.4704, Val Loss: 0.4820

# %% [markdown]
# The provided code snippet performs the following steps:
#
# 1. It defines a list of learning rates `[0.001, 0.01, 0.1]` and a list of number of epochs `[10, 20, 50, 100, 200, 500, 1000, 2000, 5000]`.
#
# 2. It calls the `grid_search` function with the training and validation data, learning rates, and number of epochs. This function performs a grid search to find the best learning rate and number of epochs based on the highest validation accuracy. The best learning rate and number of epochs are stored in the variables `best_learning_rate` and `best_num_epochs`, respectively.
#
# 3. It creates a new instance of the logistic regression model with the best learning rate and input size. It also defines the loss criterion and optimizer using the Adam optimizer with the best learning rate.
#
# 4. It prints the best learning rate and best number of epochs found during the grid search.
#
# 5. It calls the `train_model` function to train the model with the best number of epochs. It passes the model, loss criterion, optimizer, best number of epochs, and the training and validation data. This function returns the training and validation losses, as well as the training and validation accuracy scores.
#
# 6. It calls the `plot_training_stats` function to plot the training and validation accuracy scores and losses over the epochs. It passes the best number of epochs, training and validation accuracy scores, training and validation losses, and the best learning rate.
#
# 7. It calls the `evaluate_model` function to evaluate the trained model on the training and test data. It passes the model and the respective data tensors. This function returns the predicted values for the training and test data.
#
# The grid search is used to tune the hyperparameters of the logistic regression model. By performing a grid search, we iterate over different combinations of hyperparameters to find the best values that result in the highest validation accuracy. In this case, the grid search is performed on the learning rate and number of epochs.

# %%
def evaluate_classification_performance(y_true: Union[np.ndarray, list], y_pred: Union[np.ndarray, list]) -> None:
    """
    Evaluate the classification performance based on the predicted and true labels.

    Args:
        y_true (Union[np.ndarray, list]): True labels.
        y_pred (Union[np.ndarray, list]): Predicted labels.
    """

    y_pred_rounded = np.round(y_pred)

    accuracy = accuracy_score(y_true, y_pred_rounded)
    precision = precision_score(y_true, y_pred_rounded)
    recall = recall_score(y_true, y_pred_rounded)
    f1 = f1_score(y_true, y_pred_rounded)
    fpr, tpr, thresholds = roc_curve(y_true, y_pred)
    roc_auc = roc_auc_score(y_true, y_pred)
    cm = confusion_matrix(y_true, y_pred_rounded)

    print("Accuracy: {:.2%}".format(accuracy))
    print("Precision: {:.2%}".format(precision))
    print("Recall: {:.2%}".format(recall))
    print("F1 Score: {:.2%}".format(f1))
    print("ROC AUC: {:.2%}".format(roc_auc))
    print("Confusion Matrix:")
    print(cm)

    # Plot ROC curve
    plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(roc_auc))
    plt.plot([0, 1], [0, 1], linestyle='--', color='r', label='Random Guess')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

    # Plot confusion matrix
    labels = np.unique(y_true)
    sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=labels, yticklabels=labels)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

y_true = y_test_tensor.cpu().numpy()
y_pred = predicted_test

evaluate_classification_performance(y_true, y_pred)
# Out:
# Accuracy: 75.60%
# Precision: 73.96%
# Recall: 66.67%
# F1 Score: 70.12%
# ROC AUC: 83.31%
# Confusion Matrix:
# [[787 169]
#  [240 480]]

# %% [markdown]
# The code you provided defines a function evaluate_classification_performance that takes the true labels (y_true) and predicted labels (y_pred) as input and evaluates the classification performance of the model. Here's a breakdown of what the function does:
#
# 1. It rounds the predicted labels (y_pred) using np.round to convert them into binary values (0 or 1) since the logistic regression model predicts probabilities.
#
# 2. It calculates various classification metrics such as `accuracy, precision, recall, F1 score, ROC curve, ROC AUC, and the confusion matrix` using functions from `scikit-learn` (`accuracy_score, precision_score, recall_score, f1_score, roc_curve, roc_auc_score, confusion_matrix`).
#
# 3. It prints the computed metrics, including `accuracy, precision, recall, F1 score, ROC AUC, and the confusion matrix`.
#
# 4. It plots the `ROC curve` using `plt.plot`.
#
# 5. It plots the `confusion matrix` using `sns.heatmap`.
#
# Finally, the function is called with the `true labels (y_true)` and `predicted labels (y_pred)` obtained from the evaluation of the logistic regression model on the test set.
#
# This function provides a comprehensive analysis of the model's classification performance, allowing you to assess its accuracy, precision, recall, F1 score, and visualize the ROC curve and confusion matrix.

# %% [markdown]
# # Going a bit further
# ---

# %%
def create_ratings_pipeline() -> make_pipeline:
    """
    Create a pipeline for preprocessing rating features.

    Returns:
        make_pipeline: Rating feature preprocessing pipeline.
    """
    return make_pipeline(
        SimpleImputer(strategy='most_frequent'),
        StandardScaler()
    )

def create_demographics_num_pipeline() -> make_pipeline:
    """
    Create a pipeline for preprocessing numeric demographic features.

    Returns:
        make_pipeline: Numeric demographic feature preprocessing pipeline.
    """
    return make_pipeline(
        SimpleImputer(strategy='mean'),
        StandardScaler()
    )

def create_demographics_cat_pipeline() -> make_pipeline:
    """
    Create a pipeline for preprocessing categorical demographic features.

    Returns:
        make_pipeline: Categorical demographic feature preprocessing pipeline.
    """
    return make_pipeline(
        SimpleImputer(strategy='most_frequent'),
        OneHotEncoder()
    )

def create_full_cleanup_pipeline(rating_features: List[str], demographic_num_features: List[str], demographic_cat_features: List[str]) -> ColumnTransformer:
    """
    Create a full cleanup pipeline for preprocessing all features.

    Args:
        rating_features (List[str]): List of rating features.
        demographic_num_features (List[str]): List of numeric demographic features.
        demographic_cat_features (List[str]): List of categorical demographic features.

    Returns:
        ColumnTransformer: Full cleanup feature preprocessing pipeline.
    """
    pipelines = [
        ('ratings', create_ratings_pipeline(), rating_features),
        ('demo_num', create_demographics_num_pipeline(), demographic_num_features),
        ('demo_cat', create_demographics_cat_pipeline(), demographic_cat_features)
    ]
    return ColumnTransformer(pipelines)

# Example usage:
rating_features = ['attr', 'sinc', 'fun', 'amb', 'shar', 'like', 'prob']
demographic_num_features = ['age', 'income']
demographics_cat_features = ['gender', 'career', 'goal', 'met']

X_df = pd.DataFrame(X_copy, columns=rating_features + demographic_num_features + demographics_cat_features)

full_cleanup_pipeline = create_full_cleanup_pipeline(rating_features, demographic_num_features, demographics_cat_features)

X_transformed = full_cleanup_pipeline.fit_transform(X_df)
X_transformed = X_transformed.toarray()

X_train_tensor, X_val_tensor, X_test_tensor, y_train_tensor, y_val_tensor, y_test_tensor = split_data(X_transformed, y)

# %% [markdown]
# The code provided defines several utility functions to create pipelines for data preprocessing and transformation. These pipelines are useful for handling different types of features in the dataset before feeding them into a machine learning model.
#
# Here are the functions and their purposes:
#
# - `create_ratings_pipeline`: This function creates a pipeline for rating features. It uses `SimpleImputer` with the strategy set to 'most_frequent' to fill any missing values with the most frequent value in the column. It then applies `StandardScaler` to standardize the feature values.
#
# - `create_demographics_num_pipeline`: This function creates a pipeline for numerical demographic features. It uses `SimpleImputer` with the strategy set to 'mean' to fill any missing values with the mean of the column. It then applies `StandardScaler` to standardize the feature values.
#
# - `create_demographics_cat_pipeline`: This function creates a pipeline for categorical demographic features. It uses `SimpleImputer` with the strategy set to 'most_frequent' to fill any missing values with the most frequent value in the column. It then applies `OneHotEncoder` to convert the categorical features into a one-hot encoded representation.
#
# - `create_full_cleanup_pipeline`: This function creates a full cleanup pipeline that combines the above pipelines for rating, numerical demographic, and categorical demographic features. It takes lists of feature names as input and associates each feature list with the corresponding pipeline. It returns a `ColumnTransformer` object that applies the specified pipelines to the corresponding features.
#
# ---
#
# - `rating_features`, `demographic_num_features`, and `demographic_cat_features` are lists of feature names corresponding to rating, numerical demographic, and categorical demographic features, respectively.
#
# - `X_df` is a pandas DataFrame that contains the input data with columns named according to the feature names.
#
# - `full_cleanup_pipeline` is created using `create_full_cleanup_pipeline` function by passing the feature lists.
#
# - `X_transformed` is obtained by applying the `full_cleanup_pipeline` to `X_df`. This transforms the input data by applying the appropriate preprocessing steps to each feature.
#
# - Finally, the transformed data is split into training, validation, and test sets using the `split_data` function.
#
# By using these pipelines, you can conveniently handle missing values, standardize numerical features, and encode categorical features in a structured and consistent manner, preparing the data for, hopefully, training a machine learning model.

# %%
model = LogisticRegression(input_size=X_transformed.shape[1]).to(device)

# Step 2: Define the loss function and optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=best_learning_rate)

# Step 3: Train the model
# num_epochs = len(X_train)
train_losses, val_losses, train_accuracy_scores, val_accuracy_scores = train_model(model, criterion, optimizer, best_num_epochs, X_train_tensor, y_train_tensor, X_val_tensor, y_val_tensor)
plot_training_stats(best_num_epochs, train_accuracy_scores, val_accuracy_scores, train_losses, val_losses, best_learning_rate)

# Step 4: Evaluate the model
predicted_train = evaluate_model(model, X_train_tensor, y_train_tensor)
predicted_test = evaluate_model(model, X_test_tensor, y_test_tensor)
# Out:
# Epoch [100/5000], Train Loss: 0.5730, Val Loss: 0.5703
# Epoch [200/5000], Train Loss: 0.5246, Val Loss: 0.5243
# Epoch [300/5000], Train Loss: 0.4932, Val Loss: 0.4970
# Epoch [400/5000], Train Loss: 0.4700, Val Loss: 0.4783
# Epoch [500/5000], Train Loss: 0.4521, Val Loss: 0.4647
# Epoch [600/5000], Train Loss: 0.4378, Val Loss: 0.4544
# Epoch [700/5000], Train Loss: 0.4262, Val Loss: 0.4463
# Epoch [800/5000], Train Loss: 0.4165, Val Loss: 0.4400
# Epoch [900/5000], Train Loss: 0.4083, Val Loss: 0.4348
# Epoch [1000/5000], Train Loss: 0.4012, Val Loss: 0.4305
# Epoch [1100/5000], Train Loss: 0.3951, Val Loss: 0.4269
# Epoch [1200/5000], Train Loss: 0.3897, Val Loss: 0.4239
# Epoch [1300/5000], Train Loss: 0.3849, Val Loss: 0.4213
# Epoch [1400/5000], Train Loss: 0.3807, Val Loss: 0.4191
# Epoch [1500/5000], Train Loss: 0.3769, Val Loss: 0.4172
# Epoch [1600/5000], Train Loss: 0.3735, Val Loss: 0.4155
# Epoch [1700/5000], Train Loss: 0.3704, Val Loss: 0.4140
# Epoch [1800/5000], Train Loss: 0.3676, Val Loss: 0.4128
# Epoch [1900/5000], Train Loss: 0.3651, Val Loss: 0.4116
# Epoch [2000/5000], Train Loss: 0.3627, Val Loss: 0.4107
# Epoch [2100/5000], Train Loss: 0.3606, Val Loss: 0.4098
# Epoch [2200/5000], Train Loss: 0.3587, Val Loss: 0.4091
# Epoch [2300/5000], Train Loss: 0.3568, Val Loss: 0.4085
# Epoch [2400/5000], Train Loss: 0.3552, Val Loss: 0.4079
# Epoch [2500/5000], Train Loss: 0.3536, Val Loss: 0.4075
# Epoch [2600/5000], Train Loss: 0.3522, Val Loss: 0.4071
# Epoch [2700/5000], Train Loss: 0.3509, Val Loss: 0.4068
# Epoch [2800/5000], Train Loss: 0.3497, Val Loss: 0.4065
# Epoch [2900/5000], Train Loss: 0.3485, Val Loss: 0.4063
# Epoch [3000/5000], Train Loss: 0.3474, Val Loss: 0.4062
# Epoch [3100/5000], Train Loss: 0.3464, Val Loss: 0.4061
# Epoch [3200/5000], Train Loss: 0.3455, Val Loss: 0.4061
# Epoch [3300/5000], Train Loss: 0.3446, Val Loss: 0.4060
# Epoch [3400/5000], Train Loss: 0.3438, Val Loss: 0.4061
# Epoch [3500/5000], Train Loss: 0.3430, Val Loss: 0.4061
# Epoch [3600/5000], Train Loss: 0.3422, Val Loss: 0.4062
# Epoch [3700/5000], Train Loss: 0.3416, Val Loss: 0.4063
# Epoch [3800/5000], Train Loss: 0.3409, Val Loss: 0.4064
# Epoch [3900/5000], Train Loss: 0.3403, Val Loss: 0.4066
# Epoch [4000/5000], Train Loss: 0.3397, Val Loss: 0.4068
# Epoch [4100/5000], Train Loss: 0.3391, Val Loss: 0.4070
# Epoch [4200/5000], Train Loss: 0.3386, Val Loss: 0.4072
# Epoch [4300/5000], Train Loss: 0.3381, Val Loss: 0.4075
# Epoch [4400/5000], Train Loss: 0.3377, Val Loss: 0.4077
# Epoch [4500/5000], Train Loss: 0.3372, Val Loss: 0.4080
# Epoch [4600/5000], Train Loss: 0.3368, Val Loss: 0.4083
# Epoch [4700/5000], Train Loss: 0.3364, Val Loss: 0.4086
# Epoch [4800/5000], Train Loss: 0.3360, Val Loss: 0.4089
# Epoch [4900/5000], Train Loss: 0.3356, Val Loss: 0.4093
# Epoch [5000/5000], Train Loss: 0.3353, Val Loss: 0.4096

# %%
y_true = y_test_tensor.cpu().numpy()
y_pred = predicted_test

evaluate_classification_performance(y_true, y_pred)
# Out:
# Accuracy: 80.19%
# Precision: 78.12%
# Recall: 74.86%
# F1 Score: 76.45%
# ROC AUC: 88.07%
# Confusion Matrix:
# [[805 151]
#  [181 539]]

# %% [markdown]
# By using the data preprocessing pipelines, we were able to handle the data more gracefully and improve your model's performance.
#
# By gracefully handling the data using these preprocessing pipelines, we were able to enhance the model's ability to learn and make accurate predictions, resulting in improved performance and more reliable insights from the evaluation metrics.

# %%
# Define the learning rate search space
learning_rates = [0.001, 0.01, 0.1]
num_epochs_list = [10, 20, 50, 100, 200, 500, 1000, 2000, 5000]
# Perform grid search for learning rate and number of epochs optimization
best_learning_rate, best_num_epochs = grid_search(X_train_tensor, y_train_tensor, X_val_tensor, y_val_tensor, learning_rates, num_epochs_list)

print(f"Best Learning Rate: {best_learning_rate:.4f}")
# Step 1: Create the model
model = LogisticRegression(input_size=X_transformed.shape[1]).to(device)

# Step 2: Define the loss function and optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=best_learning_rate)

# Step 3: Train the model
# num_epochs = len(X_train)
train_losses, val_losses, train_accuracy_scores, val_accuracy_scores = train_model(model, criterion, optimizer, best_num_epochs, X_train_tensor, y_train_tensor, X_val_tensor, y_val_tensor)
plot_training_stats(best_num_epochs, train_accuracy_scores, val_accuracy_scores, train_losses, val_losses, best_learning_rate)

# Step 4: Evaluate the model
predicted_train = evaluate_model(model, X_train_tensor, y_train_tensor)
predicted_test = evaluate_model(model, X_test_tensor, y_test_tensor)
# Out:
# Learning Rate: 0.0010, Number of Epochs: 10, Validation Accuracy: 54.14%
# Learning Rate: 0.0010, Number of Epochs: 20, Validation Accuracy: 65.92%
# Learning Rate: 0.0010, Number of Epochs: 50, Validation Accuracy: 70.25%
# Epoch [100/100], Train Loss: 0.5819, Val Loss: 0.5801
# Learning Rate: 0.0010, Number of Epochs: 100, Validation Accuracy: 74.65%
# Epoch [100/200], Train Loss: 0.5717, Val Loss: 0.5703
# Epoch [200/200], Train Loss: 0.5224, Val Loss: 0.5232
# Learning Rate: 0.0010, Number of Epochs: 200, Validation Accuracy: 76.58%
# Epoch [100/500], Train Loss: 0.5907, Val Loss: 0.5907
# Epoch [200/500], Train Loss: 0.5341, Val Loss: 0.5354
# Epoch [300/500], Train Loss: 0.5004, Val Loss: 0.5046
# Epoch [400/500], Train Loss: 0.4763, Val Loss: 0.4842
# Epoch [500/500], Train Loss: 0.4576, Val Loss: 0.4693
# Learning Rate: 0.0010, Number of Epochs: 500, Validation Accuracy: 79.05%
# Epoch [100/1000], Train Loss: 0.5746, Val Loss: 0.5720
# Epoch [200/1000], Train Loss: 0.5259, Val Loss: 0.5258
# Epoch [300/1000], Train Loss: 0.4940, Val Loss: 0.4982
# Epoch [400/1000], Train Loss: 0.4705, Val Loss: 0.4793
# Epoch [500/1000], Train Loss: 0.4525, Val Loss: 0.4656
# Epoch [600/1000], Train Loss: 0.4382, Val Loss: 0.4553
# Epoch [700/1000], Train Loss: 0.4266, Val Loss: 0.4472
# Epoch [800/1000], Train Loss: 0.4168, Val Loss: 0.4409
# Epoch [900/1000], Train Loss: 0.4086, Val Loss: 0.4357
# Epoch [1000/1000], Train Loss: 0.4015, Val Loss: 0.4314
# Learning Rate: 0.0010, Number of Epochs: 1000, Validation Accuracy: 80.98%
# Epoch [100/2000], Train Loss: 0.5763, Val Loss: 0.5748
# Epoch [200/2000], Train Loss: 0.5255, Val Loss: 0.5260
# Epoch [300/2000], Train Loss: 0.4937, Val Loss: 0.4979
# Epoch [400/2000], Train Loss: 0.4705, Val Loss: 0.4789
# Epoch [500/2000], Train Loss: 0.4525, Val Loss: 0.4651
# Epoch [600/2000], Train Loss: 0.4381, Val Loss: 0.4546
# Epoch [700/2000], Train Loss: 0.4264, Val Loss: 0.4464
# Epoch [800/2000], Train Loss: 0.4166, Val Loss: 0.4399
# Epoch [900/2000], Train Loss: 0.4083, Val Loss: 0.4346
# Epoch [1000/2000], Train Loss: 0.4012, Val Loss: 0.4303
# Epoch [1100/2000], Train Loss: 0.3950, Val Loss: 0.4267
# Epoch [1200/2000], Train Loss: 0.3896, Val Loss: 0.4237
# Epoch [1300/2000], Train Loss: 0.3848, Val Loss: 0.4211
# Epoch [1400/2000], Train Loss: 0.3806, Val Loss: 0.4189
# Epoch [1500/2000], Train Loss: 0.3768, Val Loss: 0.4170
# Epoch [1600/2000], Train Loss: 0.3734, Val Loss: 0.4154
# Epoch [1700/2000], Train Loss: 0.3703, Val Loss: 0.4140
# Epoch [1800/2000], Train Loss: 0.3675, Val Loss: 0.4127
# Epoch [1900/2000], Train Loss: 0.3650, Val Loss: 0.4116
# Epoch [2000/2000], Train Loss: 0.3627, Val Loss: 0.4107
# Learning Rate: 0.0010, Number of Epochs: 2000, Validation Accuracy: 80.76%
# Epoch [100/5000], Train Loss: 0.5902, Val Loss: 0.5893
# Epoch [200/5000], Train Loss: 0.5347, Val Loss: 0.5354
# Epoch [300/5000], Train Loss: 0.5007, Val Loss: 0.5048
# Epoch [400/5000], Train Loss: 0.4760, Val Loss: 0.4841
# Epoch [500/5000], Train Loss: 0.4570, Val Loss: 0.4690
# Epoch [600/5000], Train Loss: 0.4418, Val Loss: 0.4576
# Epoch [700/5000], Train Loss: 0.4294, Val Loss: 0.4487
# Epoch [800/5000], Train Loss: 0.4191, Val Loss: 0.4417
# Epoch [900/5000], Train Loss: 0.4104, Val Loss: 0.4361
# Epoch [1000/5000], Train Loss: 0.4030, Val Loss: 0.4315
# Epoch [1100/5000], Train Loss: 0.3966, Val Loss: 0.4277
# Epoch [1200/5000], Train Loss: 0.3910, Val Loss: 0.4245
# Epoch [1300/5000], Train Loss: 0.3861, Val Loss: 0.4217
# Epoch [1400/5000], Train Loss: 0.3817, Val Loss: 0.4194
# Epoch [1500/5000], Train Loss: 0.3778, Val Loss: 0.4174
# Epoch [1600/5000], Train Loss: 0.3743, Val Loss: 0.4157
# Epoch [1700/5000], Train Loss: 0.3711, Val Loss: 0.4142
# Epoch [1800/5000], Train Loss: 0.3682, Val Loss: 0.4129
# Epoch [1900/5000], Train Loss: 0.3656, Val Loss: 0.4118
# Epoch [2000/5000], Train Loss: 0.3632, Val Loss: 0.4108
# Epoch [2100/5000], Train Loss: 0.3610, Val Loss: 0.4099
# Epoch [2200/5000], Train Loss: 0.3590, Val Loss: 0.4092
# Epoch [2300/5000], Train Loss: 0.3572, Val Loss: 0.4085
# Epoch [2400/5000], Train Loss: 0.3555, Val Loss: 0.4080
# Epoch [2500/5000], Train Loss: 0.3539, Val Loss: 0.4075
# Epoch [2600/5000], Train Loss: 0.3524, Val Loss: 0.4071
# Epoch [2700/5000], Train Loss: 0.3511, Val Loss: 0.4068
# Epoch [2800/5000], Train Loss: 0.3498, Val Loss: 0.4065
# Epoch [2900/5000], Train Loss: 0.3486, Val Loss: 0.4063
# Epoch [3000/5000], Train Loss: 0.3475, Val Loss: 0.4061
# Epoch [3100/5000], Train Loss: 0.3465, Val Loss: 0.4060
# Epoch [3200/5000], Train Loss: 0.3456, Val Loss: 0.4059
# Epoch [3300/5000], Train Loss: 0.3447, Val Loss: 0.4059
# Epoch [3400/5000], Train Loss: 0.3438, Val Loss: 0.4059
# Epoch [3500/5000], Train Loss: 0.3430, Val Loss: 0.4059
# Epoch [3600/5000], Train Loss: 0.3423, Val Loss: 0.4060
# Epoch [3700/5000], Train Loss: 0.3416, Val Loss: 0.4061
# Epoch [3800/5000], Train Loss: 0.3409, Val Loss: 0.4062
# Epoch [3900/5000], Train Loss: 0.3403, Val Loss: 0.4064
# Epoch [4000/5000], Train Loss: 0.3397, Val Loss: 0.4065
# Epoch [4100/5000], Train Loss: 0.3391, Val Loss: 0.4067
# Epoch [4200/5000], Train Loss: 0.3386, Val Loss: 0.4069
# Epoch [4300/5000], Train Loss: 0.3381, Val Loss: 0.4072
# Epoch [4400/5000], Train Loss: 0.3376, Val Loss: 0.4074
# Epoch [4500/5000], Train Loss: 0.3372, Val Loss: 0.4077
# Epoch [4600/5000], Train Loss: 0.3368, Val Loss: 0.4080
# Epoch [4700/5000], Train Loss: 0.3363, Val Loss: 0.4083
# Epoch [4800/5000], Train Loss: 0.3360, Val Loss: 0.4086
# Epoch [4900/5000], Train Loss: 0.3356, Val Loss: 0.4089
# Epoch [5000/5000], Train Loss: 0.3352, Val Loss: 0.4092
# Learning Rate: 0.0010, Number of Epochs: 5000, Validation Accuracy: 81.21%
# Learning Rate: 0.0100, Number of Epochs: 10, Validation Accuracy: 71.66%
# Learning Rate: 0.0100, Number of Epochs: 20, Validation Accuracy: 75.54%
# Learning Rate: 0.0100, Number of Epochs: 50, Validation Accuracy: 79.12%
# Epoch [100/100], Train Loss: 0.4022, Val Loss: 0.4307
# Learning Rate: 0.0100, Number of Epochs: 100, Validation Accuracy: 80.69%
# Epoch [100/200], Train Loss: 0.4018, Val Loss: 0.4306
# Epoch [200/200], Train Loss: 0.3646, Val Loss: 0.4117
# Learning Rate: 0.0100, Number of Epochs: 200, Validation Accuracy: 80.76%
# Epoch [100/500], Train Loss: 0.4043, Val Loss: 0.4321
# Epoch [200/500], Train Loss: 0.3654, Val Loss: 0.4119
# Epoch [300/500], Train Loss: 0.3502, Val Loss: 0.4066
# Epoch [400/500], Train Loss: 0.3425, Val Loss: 0.4056
# Epoch [500/500], Train Loss: 0.3380, Val Loss: 0.4062
# Learning Rate: 0.0100, Number of Epochs: 500, Validation Accuracy: 81.13%
# Epoch [100/1000], Train Loss: 0.4002, Val Loss: 0.4299
# Epoch [200/1000], Train Loss: 0.3641, Val Loss: 0.4116
# Epoch [300/1000], Train Loss: 0.3496, Val Loss: 0.4066
# Epoch [400/1000], Train Loss: 0.3422, Val Loss: 0.4057
# Epoch [500/1000], Train Loss: 0.3378, Val Loss: 0.4064
# Epoch [600/1000], Train Loss: 0.3350, Val Loss: 0.4078
# Epoch [700/1000], Train Loss: 0.3330, Val Loss: 0.4095
# Epoch [800/1000], Train Loss: 0.3317, Val Loss: 0.4114
# Epoch [900/1000], Train Loss: 0.3306, Val Loss: 0.4133
# Epoch [1000/1000], Train Loss: 0.3298, Val Loss: 0.4152
# Learning Rate: 0.0100, Number of Epochs: 1000, Validation Accuracy: 81.21%
# Epoch [100/2000], Train Loss: 0.4030, Val Loss: 0.4317
# Epoch [200/2000], Train Loss: 0.3650, Val Loss: 0.4119
# Epoch [300/2000], Train Loss: 0.3500, Val Loss: 0.4066
# Epoch [400/2000], Train Loss: 0.3424, Val Loss: 0.4056
# Epoch [500/2000], Train Loss: 0.3379, Val Loss: 0.4062
# Epoch [600/2000], Train Loss: 0.3351, Val Loss: 0.4076
# Epoch [700/2000], Train Loss: 0.3331, Val Loss: 0.4093
# Epoch [800/2000], Train Loss: 0.3317, Val Loss: 0.4111
# Epoch [900/2000], Train Loss: 0.3306, Val Loss: 0.4130
# Epoch [1000/2000], Train Loss: 0.3299, Val Loss: 0.4149
# Epoch [1100/2000], Train Loss: 0.3293, Val Loss: 0.4168
# Epoch [1200/2000], Train Loss: 0.3288, Val Loss: 0.4187
# Epoch [1300/2000], Train Loss: 0.3285, Val Loss: 0.4205
# Epoch [1400/2000], Train Loss: 0.3282, Val Loss: 0.4222
# Epoch [1500/2000], Train Loss: 0.3280, Val Loss: 0.4238
# Epoch [1600/2000], Train Loss: 0.3279, Val Loss: 0.4254
# Epoch [1700/2000], Train Loss: 0.3278, Val Loss: 0.4269
# Epoch [1800/2000], Train Loss: 0.3277, Val Loss: 0.4283
# Epoch [1900/2000], Train Loss: 0.3276, Val Loss: 0.4296
# Epoch [2000/2000], Train Loss: 0.3275, Val Loss: 0.4309
# Learning Rate: 0.0100, Number of Epochs: 2000, Validation Accuracy: 81.13%
# Epoch [100/5000], Train Loss: 0.4001, Val Loss: 0.4293
# Epoch [200/5000], Train Loss: 0.3641, Val Loss: 0.4111
# Epoch [300/5000], Train Loss: 0.3497, Val Loss: 0.4063
# Epoch [400/5000], Train Loss: 0.3422, Val Loss: 0.4054
# Epoch [500/5000], Train Loss: 0.3378, Val Loss: 0.4062
# Epoch [600/5000], Train Loss: 0.3350, Val Loss: 0.4076
# Epoch [700/5000], Train Loss: 0.3330, Val Loss: 0.4094
# Epoch [800/5000], Train Loss: 0.3316, Val Loss: 0.4112
# Epoch [900/5000], Train Loss: 0.3306, Val Loss: 0.4131
# Epoch [1000/5000], Train Loss: 0.3298, Val Loss: 0.4151
# Epoch [1100/5000], Train Loss: 0.3293, Val Loss: 0.4170
# Epoch [1200/5000], Train Loss: 0.3288, Val Loss: 0.4189
# Epoch [1300/5000], Train Loss: 0.3285, Val Loss: 0.4207
# Epoch [1400/5000], Train Loss: 0.3282, Val Loss: 0.4224
# Epoch [1500/5000], Train Loss: 0.3280, Val Loss: 0.4240
# Epoch [1600/5000], Train Loss: 0.3279, Val Loss: 0.4256
# Epoch [1700/5000], Train Loss: 0.3278, Val Loss: 0.4271
# Epoch [1800/5000], Train Loss: 0.3277, Val Loss: 0.4285
# Epoch [1900/5000], Train Loss: 0.3276, Val Loss: 0.4299
# Epoch [2000/5000], Train Loss: 0.3275, Val Loss: 0.4312
# Epoch [2100/5000], Train Loss: 0.3275, Val Loss: 0.4324
# Epoch [2200/5000], Train Loss: 0.3274, Val Loss: 0.4336
# Epoch [2300/5000], Train Loss: 0.3274, Val Loss: 0.4348
# Epoch [2400/5000], Train Loss: 0.3274, Val Loss: 0.4359
# Epoch [2500/5000], Train Loss: 0.3273, Val Loss: 0.4370
# Epoch [2600/5000], Train Loss: 0.3273, Val Loss: 0.4381
# Epoch [2700/5000], Train Loss: 0.3273, Val Loss: 0.4392
# Epoch [2800/5000], Train Loss: 0.3273, Val Loss: 0.4402
# Epoch [2900/5000], Train Loss: 0.3273, Val Loss: 0.4412
# Epoch [3000/5000], Train Loss: 0.3272, Val Loss: 0.4422
# Epoch [3100/5000], Train Loss: 0.3272, Val Loss: 0.4432
# Epoch [3200/5000], Train Loss: 0.3272, Val Loss: 0.4442
# Epoch [3300/5000], Train Loss: 0.3272, Val Loss: 0.4451
# Epoch [3400/5000], Train Loss: 0.3272, Val Loss: 0.4461
# Epoch [3500/5000], Train Loss: 0.3272, Val Loss: 0.4470
# Epoch [3600/5000], Train Loss: 0.3272, Val Loss: 0.4479
# Epoch [3700/5000], Train Loss: 0.3272, Val Loss: 0.4489
# Epoch [3800/5000], Train Loss: 0.3272, Val Loss: 0.4498
# Epoch [3900/5000], Train Loss: 0.3272, Val Loss: 0.4507
# Epoch [4000/5000], Train Loss: 0.3271, Val Loss: 0.4516
# Epoch [4100/5000], Train Loss: 0.3271, Val Loss: 0.4524
# Epoch [4200/5000], Train Loss: 0.3271, Val Loss: 0.4533
# Epoch [4300/5000], Train Loss: 0.3271, Val Loss: 0.4542
# Epoch [4400/5000], Train Loss: 0.3271, Val Loss: 0.4551
# Epoch [4500/5000], Train Loss: 0.3271, Val Loss: 0.4559
# Epoch [4600/5000], Train Loss: 0.3271, Val Loss: 0.4568
# Epoch [4700/5000], Train Loss: 0.3271, Val Loss: 0.4577
# Epoch [4800/5000], Train Loss: 0.3271, Val Loss: 0.4585
# Epoch [4900/5000], Train Loss: 0.3271, Val Loss: 0.4594
# Epoch [5000/5000], Train Loss: 0.3271, Val Loss: 0.4602
# Learning Rate: 0.0100, Number of Epochs: 5000, Validation Accuracy: 80.91%
# Learning Rate: 0.1000, Number of Epochs: 10, Validation Accuracy: 79.49%
# Learning Rate: 0.1000, Number of Epochs: 20, Validation Accuracy: 79.19%
# Learning Rate: 0.1000, Number of Epochs: 50, Validation Accuracy: 80.69%
# Epoch [100/100], Train Loss: 0.3294, Val Loss: 0.4189
# Learning Rate: 0.1000, Number of Epochs: 100, Validation Accuracy: 81.13%
# Epoch [100/200], Train Loss: 0.3294, Val Loss: 0.4184
# Epoch [200/200], Train Loss: 0.3276, Val Loss: 0.4308
# Learning Rate: 0.1000, Number of Epochs: 200, Validation Accuracy: 81.13%
# Epoch [100/500], Train Loss: 0.3295, Val Loss: 0.4185
# Epoch [200/500], Train Loss: 0.3276, Val Loss: 0.4309
# Epoch [300/500], Train Loss: 0.3273, Val Loss: 0.4382
# Epoch [400/500], Train Loss: 0.3272, Val Loss: 0.4437
# Epoch [500/500], Train Loss: 0.3272, Val Loss: 0.4482
# Learning Rate: 0.1000, Number of Epochs: 500, Validation Accuracy: 80.91%
# Epoch [100/1000], Train Loss: 0.3295, Val Loss: 0.4184
# Epoch [200/1000], Train Loss: 0.3276, Val Loss: 0.4307
# Epoch [300/1000], Train Loss: 0.3273, Val Loss: 0.4380
# Epoch [400/1000], Train Loss: 0.3272, Val Loss: 0.4434
# Epoch [500/1000], Train Loss: 0.3272, Val Loss: 0.4478
# Epoch [600/1000], Train Loss: 0.3271, Val Loss: 0.4517
# Epoch [700/1000], Train Loss: 0.3271, Val Loss: 0.4550
# Epoch [800/1000], Train Loss: 0.3271, Val Loss: 0.4580
# Epoch [900/1000], Train Loss: 0.3271, Val Loss: 0.4607
# Epoch [1000/1000], Train Loss: 0.3271, Val Loss: 0.4632
# Learning Rate: 0.1000, Number of Epochs: 1000, Validation Accuracy: 80.84%
# Epoch [100/2000], Train Loss: 0.3295, Val Loss: 0.4184
# Epoch [200/2000], Train Loss: 0.3276, Val Loss: 0.4305
# Epoch [300/2000], Train Loss: 0.3273, Val Loss: 0.4378
# Epoch [400/2000], Train Loss: 0.3272, Val Loss: 0.4432
# Epoch [500/2000], Train Loss: 0.3272, Val Loss: 0.4476
# Epoch [600/2000], Train Loss: 0.3271, Val Loss: 0.4514
# Epoch [700/2000], Train Loss: 0.3271, Val Loss: 0.4547
# Epoch [800/2000], Train Loss: 0.3271, Val Loss: 0.4577
# Epoch [900/2000], Train Loss: 0.3271, Val Loss: 0.4604
# Epoch [1000/2000], Train Loss: 0.3271, Val Loss: 0.4629
# Epoch [1100/2000], Train Loss: 0.3271, Val Loss: 0.4652
# Epoch [1200/2000], Train Loss: 0.3271, Val Loss: 0.4674
# Epoch [1300/2000], Train Loss: 0.3271, Val Loss: 0.4694
# Epoch [1400/2000], Train Loss: 0.3271, Val Loss: 0.4713
# Epoch [1500/2000], Train Loss: 0.3271, Val Loss: 0.4732
# Epoch [1600/2000], Train Loss: 0.3271, Val Loss: 0.4749
# Epoch [1700/2000], Train Loss: 0.3271, Val Loss: 0.4765
# Epoch [1800/2000], Train Loss: 0.3271, Val Loss: 0.4781
# Epoch [1900/2000], Train Loss: 0.3271, Val Loss: 0.4797
# Epoch [2000/2000], Train Loss: 0.3271, Val Loss: 0.4812
# Learning Rate: 0.1000, Number of Epochs: 2000, Validation Accuracy: 80.76%
# Epoch [100/5000], Train Loss: 0.3294, Val Loss: 0.4187
# Epoch [200/5000], Train Loss: 0.3276, Val Loss: 0.4310
# Epoch [300/5000], Train Loss: 0.3273, Val Loss: 0.4384
# Epoch [400/5000], Train Loss: 0.3272, Val Loss: 0.4439
# Epoch [500/5000], Train Loss: 0.3272, Val Loss: 0.4484
# Epoch [600/5000], Train Loss: 0.3271, Val Loss: 0.4523
# Epoch [700/5000], Train Loss: 0.3271, Val Loss: 0.4556
# Epoch [800/5000], Train Loss: 0.3271, Val Loss: 0.4587
# Epoch [900/5000], Train Loss: 0.3271, Val Loss: 0.4614
# Epoch [1000/5000], Train Loss: 0.3271, Val Loss: 0.4639
# Epoch [1100/5000], Train Loss: 0.3271, Val Loss: 0.4663
# Epoch [1200/5000], Train Loss: 0.3271, Val Loss: 0.4684
# Epoch [1300/5000], Train Loss: 0.3271, Val Loss: 0.4705
# Epoch [1400/5000], Train Loss: 0.3271, Val Loss: 0.4724
# Epoch [1500/5000], Train Loss: 0.3271, Val Loss: 0.4743
# Epoch [1600/5000], Train Loss: 0.3271, Val Loss: 0.4760
# Epoch [1700/5000], Train Loss: 0.3271, Val Loss: 0.4777
# Epoch [1800/5000], Train Loss: 0.3271, Val Loss: 0.4793
# Epoch [1900/5000], Train Loss: 0.3271, Val Loss: 0.4808
# Epoch [2000/5000], Train Loss: 0.3271, Val Loss: 0.4823
# Epoch [2100/5000], Train Loss: 0.3271, Val Loss: 0.4838
# Epoch [2200/5000], Train Loss: 0.3271, Val Loss: 0.4852
# Epoch [2300/5000], Train Loss: 0.3271, Val Loss: 0.4866
# Epoch [2400/5000], Train Loss: 0.3271, Val Loss: 0.4876
# Epoch [2500/5000], Train Loss: 0.3271, Val Loss: 0.4892
# Epoch [2600/5000], Train Loss: 0.3271, Val Loss: 0.4904
# Epoch [2700/5000], Train Loss: 0.3271, Val Loss: 0.4918
# Epoch [2800/5000], Train Loss: 0.3271, Val Loss: 0.4928
# Epoch [2900/5000], Train Loss: 0.3271, Val Loss: 0.4941
# Epoch [3000/5000], Train Loss: 0.3271, Val Loss: 0.4952
# Epoch [3100/5000], Train Loss: 0.3271, Val Loss: 0.4963
# Epoch [3200/5000], Train Loss: 0.3271, Val Loss: 0.4974
# Epoch [3300/5000], Train Loss: 0.3271, Val Loss: 0.4985
# Epoch [3400/5000], Train Loss: 0.3271, Val Loss: 0.4993
# Epoch [3500/5000], Train Loss: 0.3271, Val Loss: 0.5007
# Epoch [3600/5000], Train Loss: 0.3271, Val Loss: 0.5017
# Epoch [3700/5000], Train Loss: 0.3271, Val Loss: 0.5030
# Epoch [3800/5000], Train Loss: 0.3271, Val Loss: 0.5038
# Epoch [3900/5000], Train Loss: 0.3271, Val Loss: 0.5048
# Epoch [4000/5000], Train Loss: 0.3271, Val Loss: 0.5064
# Epoch [4100/5000], Train Loss: 0.3271, Val Loss: 0.5068
# Epoch [4200/5000], Train Loss: 0.3271, Val Loss: 0.5078
# Epoch [4300/5000], Train Loss: 0.3271, Val Loss: 0.5086
# Epoch [4400/5000], Train Loss: 0.3271, Val Loss: 0.5097
# Epoch [4500/5000], Train Loss: 0.3271, Val Loss: 0.5107
# Epoch [4600/5000], Train Loss: 0.3271, Val Loss: 0.5117
# Epoch [4700/5000], Train Loss: 0.3271, Val Loss: 0.5126
# Epoch [4800/5000], Train Loss: 0.3271, Val Loss: 0.5135
# Epoch [4900/5000], Train Loss: 0.3271, Val Loss: 0.5149
# Epoch [5000/5000], Train Loss: 0.3271, Val Loss: 0.5153
# Learning Rate: 0.1000, Number of Epochs: 5000, Validation Accuracy: 80.76%
# Best Learning Rate: 0.0010
# Epoch [100/5000], Train Loss: 0.5877, Val Loss: 0.5863
# Epoch [200/5000], Train Loss: 0.5339, Val Loss: 0.5344
# Epoch [300/5000], Train Loss: 0.5003, Val Loss: 0.5043
# Epoch [400/5000], Train Loss: 0.4757, Val Loss: 0.4838
# Epoch [500/5000], Train Loss: 0.4567, Val Loss: 0.4689
# Epoch [600/5000], Train Loss: 0.4415, Val Loss: 0.4576
# Epoch [700/5000], Train Loss: 0.4292, Val Loss: 0.4488
# Epoch [800/5000], Train Loss: 0.4190, Val Loss: 0.4418
# Epoch [900/5000], Train Loss: 0.4103, Val Loss: 0.4362
# Epoch [1000/5000], Train Loss: 0.4029, Val Loss: 0.4316
# Epoch [1100/5000], Train Loss: 0.3965, Val Loss: 0.4278
# Epoch [1200/5000], Train Loss: 0.3909, Val Loss: 0.4246
# Epoch [1300/5000], Train Loss: 0.3860, Val Loss: 0.4219
# Epoch [1400/5000], Train Loss: 0.3816, Val Loss: 0.4195
# Epoch [1500/5000], Train Loss: 0.3777, Val Loss: 0.4175
# Epoch [1600/5000], Train Loss: 0.3742, Val Loss: 0.4158
# Epoch [1700/5000], Train Loss: 0.3710, Val Loss: 0.4143
# Epoch [1800/5000], Train Loss: 0.3681, Val Loss: 0.4130
# Epoch [1900/5000], Train Loss: 0.3655, Val Loss: 0.4118
# Epoch [2000/5000], Train Loss: 0.3631, Val Loss: 0.4108
# Epoch [2100/5000], Train Loss: 0.3609, Val Loss: 0.4100
# Epoch [2200/5000], Train Loss: 0.3589, Val Loss: 0.4092
# Epoch [2300/5000], Train Loss: 0.3571, Val Loss: 0.4086
# Epoch [2400/5000], Train Loss: 0.3554, Val Loss: 0.4080
# Epoch [2500/5000], Train Loss: 0.3538, Val Loss: 0.4075
# Epoch [2600/5000], Train Loss: 0.3524, Val Loss: 0.4071
# Epoch [2700/5000], Train Loss: 0.3510, Val Loss: 0.4068
# Epoch [2800/5000], Train Loss: 0.3498, Val Loss: 0.4065
# Epoch [2900/5000], Train Loss: 0.3486, Val Loss: 0.4063
# Epoch [3000/5000], Train Loss: 0.3475, Val Loss: 0.4062
# Epoch [3100/5000], Train Loss: 0.3465, Val Loss: 0.4061
# Epoch [3200/5000], Train Loss: 0.3455, Val Loss: 0.4060
# Epoch [3300/5000], Train Loss: 0.3446, Val Loss: 0.4060
# Epoch [3400/5000], Train Loss: 0.3438, Val Loss: 0.4060
# Epoch [3500/5000], Train Loss: 0.3430, Val Loss: 0.4060
# Epoch [3600/5000], Train Loss: 0.3423, Val Loss: 0.4061
# Epoch [3700/5000], Train Loss: 0.3416, Val Loss: 0.4062
# Epoch [3800/5000], Train Loss: 0.3409, Val Loss: 0.4063
# Epoch [3900/5000], Train Loss: 0.3403, Val Loss: 0.4064
# Epoch [4000/5000], Train Loss: 0.3397, Val Loss: 0.4066
# Epoch [4100/5000], Train Loss: 0.3391, Val Loss: 0.4068
# Epoch [4200/5000], Train Loss: 0.3386, Val Loss: 0.4070
# Epoch [4300/5000], Train Loss: 0.3381, Val Loss: 0.4072
# Epoch [4400/5000], Train Loss: 0.3376, Val Loss: 0.4075
# Epoch [4500/5000], Train Loss: 0.3372, Val Loss: 0.4078
# Epoch [4600/5000], Train Loss: 0.3368, Val Loss: 0.4080
# Epoch [4700/5000], Train Loss: 0.3364, Val Loss: 0.4083
# Epoch [4800/5000], Train Loss: 0.3360, Val Loss: 0.4087
# Epoch [4900/5000], Train Loss: 0.3356, Val Loss: 0.4090
# Epoch [5000/5000], Train Loss: 0.3352, Val Loss: 0.4093

# %% [markdown]
# In an effort to improve the performance of our model, we focused on optimizing the hyperparameters.
# By adjusting these parameters, we aimed to fine-tune the model's behavior and achieve better results.

# %%
y_true = y_test_tensor.cpu().numpy()
y_pred = predicted_test

evaluate_classification_performance(y_true, y_pred)
# Out:
# Accuracy: 80.13%
# Precision: 77.84%
# Recall: 75.14%
# F1 Score: 76.47%
# ROC AUC: 88.12%
# Confusion Matrix:
# [[802 154]
#  [179 541]]

# %% [markdown]
# Although we made efforts to tweak the hyperparameters in order to enhance the model's performance, the results did not show significant improvements. Despite exploring different combinations of learning rates and number of epochs through grid search, the overall impact on the model's performance was limited.
